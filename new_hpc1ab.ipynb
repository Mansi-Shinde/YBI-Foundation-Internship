# %% [markdown]
# <a href="https://colab.research.google.com/github/Mansi-Shinde/YBI-Foundation-Internship/blob/master/new_hpc1ab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A) Design and implement Parallel BFS based on existing algorithms using openmp. Use tree or undirected grapgh for bfs

# %% [markdown]
# This C++ code demonstrates the Breadth-First Search (BFS) algorithm for traversing a binary tree. Let's go through the code step by step:
#
# cpp
# Copy code
# #include<iostream>
# #include<stdlib.h>
# #include<queue>
# using namespace std;
#
# class node {
# public:
#     node *left, *right;
#     int data;
# };
#
# class Breadthfs {
# public:
#     node *insert(node *, int);
#     void bfs(node *);
# };
#
# node *insert(node *root, int data) {
#     if (!root) {
#         root = new node;
#         root->left = NULL;
#         root->right = NULL;
#         root->data = data;
#         return root;
#     }
#
#     queue<node *> q;
#     q.push(root);
#
#     while (!q.empty()) {
#         node *temp = q.front();
#         q.pop();
#
#         if (temp->left == NULL) {
#             temp->left = new node;
#             temp->left->left = NULL;
#             temp->left->right = NULL;
#             temp->left->data = data;
#             return root;
#         } else {
#             q.push(temp->left);
#         }
#
#         if (temp->right == NULL) {
#             temp->right = new node;
#             temp->right->left = NULL;
#             temp->right->right = NULL;
#             temp->right->data = data;
#             return root;
#         } else {
#             q.push(temp->right);
#         }
#     }
# }
#
# void bfs(node *head) {
#     queue<node*> q;
#     q.push(head);
#
#     int qSize;
#
#     while (!q.empty()) {
#         qSize = q.size();
#         #pragma omp parallel for
#         for (int i = 0; i < qSize; i++) {
#             node* currNode;
#             #pragma omp critical
#             {
#                 currNode = q.front();
#                 q.pop();
#                 cout << "\t" << currNode->data;
#             }
#             #pragma omp critical
#             {
#                 if (currNode->left)
#                     q.push(currNode->left);
#                 if (currNode->right)
#                     q.push(currNode->right);
#             }
#         }
#     }
# }
#
# int main() {
#     node *root = NULL;
#     int data;
#     char ans;
#
#     do {
#         cout << "\n enter data=>";
#         cin >> data;
#
#         root = insert(root, data);
#
#         cout << "do you want insert one more node?";
#         cin >> ans;
#
#     } while (ans == 'y' || ans == 'Y');
#
#     bfs(root);
#
#     return 0;
# }
# Here's an explanation of the code:
#
# The code defines a class node, representing a node in a binary tree. It has two pointers left and right for the left and right child nodes, respectively, and an integer data to store the node value.
#
# The Breadthfs class is declared with member functions insert and bfs.
#
# The insert function inserts a node in the binary tree. It uses a level-order traversal approach using a queue to find the appropriate position for the new node.
#
# The bfs function performs a Breadth-First Search traversal of the binary tree. It uses a queue to process the nodes in a breadth-first manner. It employs OpenMP parallelization to create multiple threads for parallel processing of nodes at the same level.
#
# In the main function, the user is prompted to enter data to create nodes in the binary tree using the insert function. The tree is then traversed using the bfs function.
#
# The code utilizes OpenMP directives (#pragma omp) to parallelize the BFS algorithm

# %%
/*
Name: Alwis Shaji
Roll no: COBA001

Design and implement Parallel Breadth First Search based on existing
algorithms using OpenMP. Use a Tree or an undirected graph for BFS
*/
#include<iostream>
#include<stdlib.h>
#include<queue>
using namespace std;
class node
{
    public:
 
    node *left, *right;
    int data;
}; 

class Breadthfs
{
    public:
    node *insert(node *, int);
    void bfs(node *);
};

node *insert(node *root, int data)
// inserts a node in tree
{
    if(!root)
    {
 
        root=new node;

        root->left=NULL;
        root->right=NULL;
        root->data=data;
    
        return root;
    }
 
    queue<node *> q;
    q.push(root);
 
    while(!q.empty())
    {
        node *temp=q.front();
        q.pop();
 
        if(temp->left==NULL)
        {
 
            temp->left=new node;
            temp->left->left=NULL;
            temp->left->right=NULL;
            temp->left->data=data; 
            return root;
        }
        else
        {
            q.push(temp->left);
        }
 
        if(temp->right==NULL)
        {
 
            temp->right=new node;
            temp->right->left=NULL;
            temp->right->right=NULL;

            temp->right->data=data; 
            return root;
        }
        else
        {
            q.push(temp->right);
        }
    }
 
}

void bfs(node *head)
{
    queue<node*> q;
    q.push(head);
 
    int qSize;
 
    while (!q.empty())
    {
        qSize = q.size();
        #pragma omp parallel for
        //creates parallel threads
        for (int i = 0; i < qSize; i++)
        {
 	        node* currNode;
 	        #pragma omp critical
 	        {
 		        currNode = q.front();
 		        q.pop();
 		        cout<<"\t"<<currNode->data;
 
 	        }// prints parent node
 	        #pragma omp critical
 	        {
 		        if(currNode->left)// push parent's left node in queue
 		            q.push(currNode->left);
 		        if(currNode->right)
 		            q.push(currNode->right);
 	        }// push parent's right node in queue 
        }
    }
}

int main(){
 	node *root=NULL;
 	int data;
 	char ans;
 
    do
    {
        cout<<"\n enter data=>";
 	    cin>>data;
 
 	    root=insert(root,data);
 
 	    cout<<"do you want insert one more node?";
        cin>>ans;
 
    }while(ans=='y'||ans=='Y');
 
    bfs(root);
 
    return 0;
}

Output
enter data=>10
do you want insert one more node?y
enter data=>5
do you want insert one more node?y
enter data=>31
do you want insert one more node?y
enter data=>10
do you want insert one more node?y
enter data=>2
do you want insert one more node?n
10	5	31	10	2

# %% [markdown]
# B) Design and implement parallel DFS based on existing algo using openMp. ""

# %%
/*
Name: Alwis Shaji
Roll no: COBA001

Design and implement Parallel Depth First Search based on existing
algorithms using OpenMP. Use a Tree or an undirected graph for DFS
*/
#include <iostream>
#include <vector>
#include <stack>
#include <omp.h>
using namespace std;

const int MAX = 100000;
vector<int> graph[MAX];
bool visited[MAX];

void dfs(int node) {
    stack<int> s;
    s.push(node);
    while (!s.empty()) {
        int curr_node = s.top();
 		s.pop();
 		if (!visited[curr_node]) {
 			visited[curr_node] = true;
 		#pragma omp parallel for
 		for (int i = 0; i < graph[curr_node].size(); i++) {
 			int adj_node = graph[curr_node][i];
 			if (!visited[adj_node]) {
 				s.push(adj_node);
            }
        }
 		}
    }
}

int main() {
    
    int n, m, start_node;
    cin >> n >> m >> start_node;
    
    //n: node,m:edges
    for (int i = 0; i < m; i++) {
    int u, v;
    cin >> u >> v;

    //u and v: Pair of edges
    graph[u].push_back(v);
    graph[v].push_back(u);
    }
    
    #pragma omp parallel for
    for(int i = 0; i < n; i++) {
    visited[i] = false;
    }
    dfs(start_node);
    for(int i = 0; i < n; i++) {
    if(visited[i]) {
        cout << i << " ";
    }
    }
    
    return 0;
}

op 
6 7 0

# %% [markdown]
# **Aditi**

# %% [markdown]
# The main function reads the input for the number of nodes (n), number of edges (m), and the starting node. It then reads the edges and builds the adjacency list representation of the graph.
#
# After initializing the visited array to false, the code parallelizes the initialization loop using #pragma omp parallel for directive.
#
# The dfs function is called with the starting node to perform the depth-first search.
#
# Finally, the code prints the nodes that have been visited (marked as true in the visited array).
#
# The OpenMP directive #pragma omp parallel for is used to parallelize the initialization loop and potentially speed up the execution by utilizing multiple threads to process the loop iterations concurrently.
#
# Note: For the code to compile and run successfully with OpenMP, you need to have a compiler that supports OpenMP and enable the OpenMP flag during compilation (e.g., -fopenmp for GCC).

# %%
#include <iostream>
#include <vector>
#include <stack>
#include <omp.h>

using namespace std;

const int MAX = 100000;
vector<int> graph[MAX];
bool visited[MAX];

void dfs(int node) {
	stack<int> s;
	s.push(node);

	while (!s.empty()) {
    	int curr_node = s.top();
    	s.pop();

    	if (!visited[curr_node]) {
        	visited[curr_node] = true;
        	
        	if (visited[curr_node]) {
        	cout << curr_node << " ";
    	}

        	#pragma omp parallel for
        	for (int i = 0; i < graph[curr_node].size(); i++) {
            	int adj_node = graph[curr_node][i];
            	if (!visited[adj_node]) {
                	s.push(adj_node);
            	}
        	}
    	}
	}
}

int main() {
	int n, m, start_node;
	cout << "Enter No of Node,Edges,and start node:" ;
	cin >> n >> m >> start_node;
         //n: node,m:edges
         
cout << "Enter Pair of edges:" ;
	for (int i = 0; i < m; i++) {
    	int u, v;
    		
    	cin >> u >> v;
//u and v: Pair of edges
    	graph[u].push_back(v);
    	graph[v].push_back(u);
	}

	#pragma omp parallel for
	for (int i = 0; i < n; i++) {
    	visited[i] = false;
	}

	dfs(start_node);

	for (int i = 0; i < n; i++) {
    	if (visited[i]) {
        	cout << i << " ";
    	}
	}

	return 0;
}
